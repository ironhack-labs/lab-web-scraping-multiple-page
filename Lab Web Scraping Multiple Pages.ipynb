# %%
# importing lybrairy plus url
import pandas as pd
import requests 

# steps number 1  always 

url ='https://en.wikipedia.org/wiki/Python'

# STEPS 2 -> GET THE RESPONSE 

response = requests.get(url)

response
# Out:
# <Response [200]>

# %% [markdown]
# # Retrieve an arbitrary Wikipedia page of "Python" and create a list of links on that page: url ='https://en.wikipedia.org/wiki/Python'

# %%
# content of the website 

response.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Python - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-widt
# ...

# %%
# extracting website content as a Variable soup
from bs4 import BeautifulSoup
# step 3 create the soup
soup = BeautifulSoup(response.content,'html.parser') # if html.parsr does not work try xlm or lxlm

# %%
# getting the link from the soup, iterating toi get every link

link_wiki = [a['href'] for a in soup.find_all('a', href=True) if a ]

# %%
link_wiki
# Out:
# ['#bodyContent',
#  '/wiki/Main_Page',
#  '/wiki/Wikipedia:Contents',
#  '/wiki/Portal:Current_events',
#  '/wiki/Special:Random',
#  '/wiki/Wikipedia:About',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  '/wiki/Help:Contents',
#  '/wiki/Help:Introduction',
#  '/wiki/Wikipedia:Community_portal',
#  '/wiki/Special:RecentChanges',
#  '/wiki/Wikipedia:File_upload_wizard',
#  '/wiki/Main_Page',
#  '/wiki/Special:Search',
#  '/w/index.php?title=Special:CreateAccount&returnto=Python',
#  '/w/index.php?title=Special:UserLogin&returnto=Python',
#  '/w/index.php?title=Special:CreateAccount&returnto=Python',
#  '/w/index.php?title=Special:UserLogin&returnto=Python',
#  '/wiki/Help:Introduction',
#  '/wiki/Special:MyContributions',
#  '/wiki/Special:MyTalk',
#  '#',
#  '#Snakes',
#  '#Computing',
#  '#People',
#  '#Roller_coasters',
# ...

# %%
# selecting all the link with https 

list_https = []

for a_tag in link_wiki:
    
    if 'https' in a_tag:
        list_https.append(a_tag)

# %%
list_https
# Out:
# ['https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  'https://af.wikipedia.org/wiki/Python',
#  'https://als.wikipedia.org/wiki/Python',
#  'https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86_(%D8%AA%D9%88%D8%B6%D9%8A%D8%AD)',
#  'https://az.wikipedia.org/wiki/Python_(d%C9%99qiql%C9%99%C5%9Fdirm%C9%99)',
#  'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)',
#  'https://be.wikipedia.org/wiki/Python',
#  'https://bg.wikipedia.org/wiki/%D0%9F%D0%B8%D1%82%D0%BE%D0%BD_(%D0%BF%D0%BE%D1%8F%D1%81%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5)',
#  'https://cs.wikipedia.org/wiki/Python_(rozcestn%C3%ADk)',
#  'https://da.wikipedia.org/wiki/Python',
#  'https://de.wikipedia.org/wiki/Python',
# ...

# %% [markdown]
# # Display the top 10 languages by number of native speakers stored in a pandas dataframe: url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# importing lybrairy plus url
import pandas as pd
import requests 

# steps number 1  always 

url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# STEPS 2 -> GET THE RESPONSE 

response_wiky_2 = requests.get(url)

# %%
# content of the website 

response_wiky_2.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of languages by number of native speakers - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-
# ...

# %%
# extracting website content as a Variable soup
from bs4 import BeautifulSoup
# step 3 create the soup
soup_wiky2 = BeautifulSoup(response.content,'html.parser') # if html.parsr does not work try xlm or lxlm

# %%
# getting the whole page

soup_wiky2
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Python - Wikipedia</title>
# ...

# %%
# getting only the language table with find

table = soup_wiky2.find('table')

# %%
table

# %%
import pandas as pd
from io import StringIO



# Use pandas to read HTML tables from the StringIO object
table2 = pd.read_html(str(table))[0]


table2
# Out:
# C:\Users\Tracy\AppData\Local\Temp\ipykernel_12660\125469621.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   table2 = pd.read_html(str(table))[0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 7
#       2 from io import StringIO
#       6 # Use pandas to read HTML tables from the StringIO object
# ----> 7 table2 = pd.read_html(str(table))[0]
#      10 table2
#
# File d:\Anaconda\Lib\site-packages\pandas\io\html.py:1245, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1229 if isinstance(io, str) and not any(
#    1230     [
#    1231         is_file_like(io),
# ...

# %%
# reading HTLM table with read_html from panda, setting to hae the first table
import pandas as pd
df_language_wicky = pd.read_html(str(table))[0]
# Out:
# C:\Users\Tracy\AppData\Local\Temp\ipykernel_12660\3592844083.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_language_wicky = pd.read_html(str(table))[0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 3
#       1 # reading HTLM table with read_html from panda, setting to hae the first table
#       2 import pandas as pd
# ----> 3 df_language_wicky = pd.read_html(str(table))[0]
#
# File d:\Anaconda\Lib\site-packages\pandas\io\html.py:1245, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1229 if isinstance(io, str) and not any(
#    1230     [
# ...

# %%
df_language_wicky
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df_language_wicky
#
# NameError: name 'df_language_wicky' is not defined

# %% [markdown]
# # A list with the different kind of datasets available in data.gov.uk: url = 'https://data.gov.uk/'

# %%
# importing lybrairy plus url
import pandas as pd
import requests 

# steps number 1  always 

url = 'https://www.data.gov.uk/'

# STEPS 2 -> GET THE RESPONSE 

response_gov_uk = requests.get(url)

# %%
# extracting website content as a Variable soup
from bs4 import BeautifulSoup
# step 3 create the soup
soup_gov_uk = BeautifulSoup(response_gov_uk.content,'html.parser') # if html.parsr does not work try xlm or lxlm

# %%
gov_uk_list = []

for title in soup_gov_uk.find_all('h3') :
    gov_uk_list.append(title.text.strip())

# %%
gov_uk_list
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport',
#  'Digital service performance',
#  'Government reference data']

# %% [markdown]
# # List all language names and number of related articles in the order they appear in wikipedia.org: url = 'https://www.wikipedia.org/'

# %%
# importing lybrairy plus url
import pandas as pd
import requests 

# steps number 1  always 

url = 'https://www.wikipedia.org/'

# STEPS 2 -> GET THE RESPONSE 

response_wik_org = requests.get(url)

# %%
# extracting website content as a Variable soup
from bs4 import BeautifulSoup
# step 3 create the soup
soup_wik_org = BeautifulSoup(response_wik_org.content,'html.parser') # if html.parsr does not work try xlm or lxlm

# %%
# iterating and cleaning data from the soup

wik_org_list = []

for lang in soup_wik_org.find_all('strong') :
    wik_org_list.append(lang.text.strip())

# %%
# removing the not useful title selected 

wik_org_list =wik_org_list[1:11]

# %%
# list with all the language on wikipedai

wik_org_list
# Out:
# ['English',
#  'Русский',
#  '日本語',
#  'Español',
#  'Deutsch',
#  'Français',
#  'Italiano',
#  '中文',
#  'العربية',
#  'فارسی']

# %% [markdown]
# # Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe: url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# importing lybrairy plus url
import pandas as pd
import requests 

# steps number 1  always 

url = 'https://www.emsc-csem.org/Earthquake/'

# STEPS 2 -> GET THE RESPONSE 

Earthquake = requests.get(url)

# %%
from bs4 import BeautifulSoup
# step 3 create the soup
Earthquake_soup = BeautifulSoup(Earthquake.content,'html.parser') # if html.parsr does not work try xlm or lxlm

# %%
Earthquake_list = []

Earthquake_soup.find('table')
# Out:
# <table><tr><th></th><th>Period</th><th>Magnitude</th><th class="moref">Depth</th><th class="moref">Latitude</th><th class="moref">Longitude</th>
# <th class="moref"></th><th class="moref">Reports</th><th class="moref">Images</th><th class="moref">Comments</th>
# </tr>
# <tr><td>Min: </td><td><input aria-label="date min" id="datemin" max="2024-02-06" min="2004-10-01" name="datemin" type="date"/></td><td><input aria-label="magnitude min" id="magmin" max="11" min="0" name="magmin" step="0.1" type="number"/></td><td><input aria-label="depth min" class="moref" id="depthmin" max="10000" min="-10" name="depthmin" step="1" type="number"/></td>
# <td><input aria-label="latitude min" class="moref" id="latmin" max="90" min="-90" name="latmin" step="0.001" type="number"/></td>
# <td class="ic"><input aria-label="longitude min" class="moref" id="lonmin" max="180" min="-180" name="lonmin" step="0.001" type="number"/></td>
# ...

# %%
 # for lang in Earthquake_list.append(lang.text.strip())

# %%
import pandas as pd
from bs4 import BeautifulSoup

# The HTML code you provided
soup2 = Earthquake_soup.find_all('div',class_="htab")

# %%
soup2
# Out:
# [<div class="htab"><table class="eqs table-scroll">
#  <thead><tr><th class="thico"><th class="citiz" colspan="2"><div>Citizen<br/>response</div><div><div class="dm comm"></div><div class="dm pic"></div></div></th>
#  </th><th class="tbdat">Date &amp; Time<div>UTC</div></th><th class="tblat">Lat.<div>degrees</div></th><th class="tblon">Lon.<div>degrees</div></th><th class="tbdep">Depth<div>km</div></th><th class="tbmag">Mag.<span>[+]</span></th><th class="tbreg">Region</th></tr></thead>
#  <tbody></tbody>
#  </table>
#  </div>]
