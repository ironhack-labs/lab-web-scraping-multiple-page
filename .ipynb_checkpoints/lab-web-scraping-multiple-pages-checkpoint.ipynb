# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # 1. Retrieve an arbitrary Wikipedia page of "Python" and create a list of links on that page: url ='https://en.wikipedia.org/wiki/Python'

# %%
url = 'https://en.wikipedia.org/wiki/Python'
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup.find_all('a')
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>,
#  <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>,
#  <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>,
#  <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>,
#  <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>,
#  <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>,
#  <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>,
# ...

# %%
links = []

for link in soup.find_all('a'):
    links.append(link.get('href'))
    
links
# Out:
# ['#bodyContent',
#  '/wiki/Main_Page',
#  '/wiki/Wikipedia:Contents',
#  '/wiki/Portal:Current_events',
#  '/wiki/Special:Random',
#  '/wiki/Wikipedia:About',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  '/wiki/Help:Contents',
#  '/wiki/Help:Introduction',
#  '/wiki/Wikipedia:Community_portal',
#  '/wiki/Special:RecentChanges',
#  '/wiki/Wikipedia:File_upload_wizard',
#  '/wiki/Main_Page',
#  '/wiki/Special:Search',
#  '/w/index.php?title=Special:CreateAccount&returnto=Python',
#  '/w/index.php?title=Special:UserLogin&returnto=Python',
#  '/w/index.php?title=Special:CreateAccount&returnto=Python',
#  '/w/index.php?title=Special:UserLogin&returnto=Python',
#  '/wiki/Help:Introduction',
#  '/wiki/Special:MyContributions',
#  '/wiki/Special:MyTalk',
#  '#',
#  '#Snakes',
#  '#Computing',
#  '#People',
#  '#Roller_coasters',
# ...

# %%
print(len(links))
# Out:
# 163

# %% [markdown]
# # Find the number of titles that have changed in the United States Code since its last release point: url = 'http://uscode.house.gov/download/download.shtml'

# %%
url = 'https://uscode.house.gov/download/download.shtml'
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup.find('div', class_='usctitlechanged')
# Out:
# <div class="usctitlechanged" id="us/usc/t42">
#
#           Title 42 - The Public Health and Welfare
#
#         </div>

# %%
titles = []

for title in soup.find_all('div', class_='usctitlechanged'):
    titles.append(title.getText().strip())
    
titles

numbers = [int(title.split(' ')[1]) for title in titles]


print(numbers)
# Out:
# [42, 50]

# %% [markdown]
# # Create a Python list with the top ten FBI's Most Wanted names: url = 'https://www.fbi.gov/wanted/topten'

# %%
url = 'https://www.fbi.gov/wanted/topten'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}
response = requests.get(url, headers=headers)
response
# Out:
# <Response [403]>

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage to scrape
url = 'https://www.fbi.gov/wanted/topten'

# Define the headers to mimic a web browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "Referer": "https://www.google.com/",
    "Connection": "keep-alive",
}

# Send a GET request to the webpage
response = requests.get(url, headers=headers)

# Check the status code of the response
print(response)

# Proceed only if the response is successful
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, "html.parser")
    # Proceed with your scraping logic here
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# <Response [403]>
# Failed to retrieve the webpage. Status code: 403

# %%
#pip install selenium

# %%
# Didn't work

# %% [markdown]
# # List all language names and number of related articles in the order they appear in wikipedia.org: url = 'https://www.wikipedia.org/'

# %%
url = 'https://www.wikipedia.org/'
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
langs = soup.select('a.link-box > strong')

languages = []

for lan in langs:
    languages.append(lan.getText().strip())
languages
# Out:
# ['English',
#  '日本語',
#  'Deutsch',
#  'Русский',
#  'Español',
#  'Français',
#  '中文',
#  'Italiano',
#  'فارسی',
#  'Português']

# %%
nums = soup.select('a.link-box > small')

numbers = []

for num in nums:
    numbers.append(num.getText().strip())
numbers
# Out:
# ['6,847,000+ articles',
#  '1,421,000+ 記事',
#  '2.924.000+ Artikel',
#  '1\xa0987\xa0000+ статей',
#  '1.965.000+ artículos',
#  '2\u202f621\u202f000+ articles',
#  '1,429,000+ 条目 / 條目',
#  '1.871.000+ voci',
#  '۱٬۰۰۶٬۰۰۰+ مقاله',
#  '1.128.000+ artigos']

# %%
import re

numbers = [
    '6,847,000+ articles',
    '1,421,000+ 記事',
    '2.924.000+ Artikel',
    '1\xa0987\xa0000+ статей',
    '1.965.000+ artículos',
    '2\u202f621\u202f000+ articles',
    '1,429,000+ 条目 / 條目',
    '1.871.000+ voci',
    '۱٬۰۰۶٬۰۰۰+ مقاله',
    '1.128.000+ artigos'
]

def extract_number(string):

    number = re.sub(r'\D', '', string)
 
    return int(number)

numbers = [extract_number(item) for item in numbers]

print(numbers)
# Out:
# [6847000, 1421000, 2924000, 1987000, 1965000, 2621000, 1429000, 1871000, 1006000, 1128000]

# %%
df = pd.DataFrame({
    'Languages': languages,
    'Numbers': numbers
})
df
# Out:
#    Languages  Numbers
# 0    English  6847000
# 1        日本語  1421000
# 2    Deutsch  2924000
# 3    Русский  1987000
# 4    Español  1965000
# 5   Français  2621000
# 6         中文  1429000
# 7   Italiano  1871000
# 8      فارسی  1006000
# 9  Português  1128000
