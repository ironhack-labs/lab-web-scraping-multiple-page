# %%
##Lab | Web Scraping Multiple Pages

# %%
#import librarys 
import requests 
from bs4 import BeautifulSoup

# %%
#save the url 
url = "https://en.wikipedia.org/wiki/List_of_songs_recorded_by_Arctic_Monkeys"
response = requests.get(url)

# %%
#get the content of the page 
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup.find_all('th')
# Out:
# [<th>Contents
#  </th>,
#  <th scope="row" style="background-color:#CCFFFF"><img alt="Indicate songs not written by members of Arctic Monkeys" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/f/f9/Double-dagger-14-plain.png" width="9">
#  </img></th>,
#  <th scope="col">Title
#  </th>,
#  <th scope="col">Songwriter(s)
#  </th>,
#  <th scope="col">Original release
#  </th>,
#  <th scope="col">Year
#  </th>,
#  <th class="unsortable" scope="col">Ref.
#  </th>,
#  <th scope="row"><span class="anchor" id="0–9"></span>"-"<sup class="reference" id="cite_ref-36"><a href="#cite_note-36">[a]</a></sup><sup class="reference" id="cite_ref-37"><a href="#cite_note-37">[b]</a></sup><br/><small>(<a href="/wiki/Stephen_Fretwell" title="Stephen Fretwell">Stephen Fretwell</a> cover)</small>
#  </th>,
#  <th scope="row"><span class="anchor" id="0–9"></span> "2013"
#  </th>,
#  <th scope="row">"505"
#  </th>,
#  <th scope="row">"7"
# ...

# %%
song = []

i = 1
r = 8
while i <= 100:
    song = soup.select('th')[r].text.strip()
    print(i, song)
    i += 1
    r += 1
# Out:
# 1 "2013"
# 2 "505"
# 3 "7"
# 4 "The Afternoon's Hat"
# 5 "All My Own Stunts"
# 6 "American Sports"
# 7 "Anyways"[c]
# 8 "Arabella"
# 9 "Baby I'm Yours" (with The 747s)[d](Barbara Lewis cover)
# 10 "The Bad Thing"
# 11 "Bad Woman" (with Richard Hawley)[e](Pat Farrell and the Believers cover)
# 12 "The Bakery"
# 13 "Balaclava"
# 14 "Batphone"
# 15 "Body Paint"
# 16 "Bigger Boys and Stolen Sweethearts"
# 17 "Big Ideas"
# 18 "Black Treacle"
# 19 "The Blond-O-Sonic Shimmer Trap"
# 20 "Brianstorm"
# 21 "Brick by Brick"
# 22 "The Car"
# 23 "Catapult"
# 24 "A Certain Romance"
# 25 "Chun Li's Spinning Bird Kick"
# 26 "Cigarette Smoker Fiona"
# 27 "Cornerstone"
# 28 "Crying Lightning"
# 29 "D Is for Dangerous"
# 30 "Da Frame 2R"[f]
# 31 "Dance Little Liar"
# 32 "Dancing Shoes"
# 33 "Dangerous Animals"
# 34 "The Death Ramps"
# 35 "Despair in the Departure Lounge"
# 36 "Diamonds Are Forever"(Shirley Bassey cover)
# 37 "Do I Wanna Know?"
# 38 "Do Me a Favour"
# ...

# %%
#1 Retrieve an arbitrary Wikipedia page of "Python" and create a list of links on that page: url ='https://en.wikipedia.org/wiki/Python'
#save the url 
links = []
url1 = "https://en.wikipedia.org/wiki/Python"
response1 = requests.get(url1)

# %%
soup1 = BeautifulSoup(response2.text, "html.parser")

# %%
soup1.find_all('a')
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>,
#  <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>,
#  <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>,
#  <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>,
#  <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>,
#  <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>,
#  <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>,
# ...

# %%
for link in soup1.find_all('a'):
    href = link.get('href')
    if href is not None and href.startswith('http'):
        links.append(href)

# %%
import pandas as pd

# %%
links = pd.DataFrame(links)

# %%
links
# Out:
#                                                     0
# 0   https://donate.wikimedia.org/wiki/Special:Fund...
# 1                https://af.wikipedia.org/wiki/Python
# 2               https://als.wikipedia.org/wiki/Python
# 3   https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%...
# 4   https://az.wikipedia.org/wiki/Python_(d%C9%99q...
# 5   https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%...
# 6                https://be.wikipedia.org/wiki/Python
# 7   https://bg.wikipedia.org/wiki/%D0%9F%D0%B8%D1%...
# 8   https://cs.wikipedia.org/wiki/Python_(rozcestn...
# 9                https://da.wikipedia.org/wiki/Python
# 10               https://de.wikipedia.org/wiki/Python
# 11  https://eo.wikipedia.org/wiki/Pitono_(apartigilo)
# 12    https://eu.wikipedia.org/wiki/Python_(argipena)
# 13  https://fa.wikipedia.org/wiki/%D9%BE%D8%A7%DB%...
# 14               https://fr.wikipedia.org/wiki/Python
# 15  https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%...
# ...

# %%
#2 Find the number of titles that have changed in the United States Code since its last release point: url = 'http://uscode.house.gov/download/download.shtml'
url2 = "http://uscode.house.gov/download/download.shtml"
response2 = requests.get(url2)
soup2 = BeautifulSoup(response2.text, "html.parser")

# %%
text = soup2.select('#us\/usc\/t1')[0].get_text()
text.strip()
# Out:
# 'Title 1 - General Provisions ٭'

# %%
changed_title_divs = soup2.find_all('div', class_='usctitlechanged')

changed_titles = []
for div in changed_title_divs:
    title_text = div.get_text().strip()
    changed_titles.append(title_text)

changed_titles = pd.DataFrame(changed_titles)
print(changed_titles)
# Out:
#                                                     0
# 0                      Title 1 - General Provisions ٭
# 1                              Title 2 - The Congress
# 2                           Title 3 - The President ٭
# 3   Title 5 - Government Organization and Employees ٭
# 4                         Title 6 - Domestic Security
# 5                    Title 8 - Aliens and Nationality
# 6                           Title 10 - Armed Forces ٭
# 7                        Title 12 - Banks and Banking
# 8                            Title 14 - Coast Guard ٭
# 9                       Title 15 - Commerce and Trade
# 10                            Title 16 - Conservation
# 11                            Title 17 - Copyrights ٭
# 12         Title 18 - Crimes and Criminal Procedure ٭
# 13                               Title 20 - Education
# 14                          Title 21 - Food and Drugs
# 15       Title 22 - Foreign Relations and Intercourse
# ...

# %%
#3 Create a Python list with the top ten FBI's Most Wanted names: url = 'https://www.fbi.gov/wanted/topten'
url3 = "https://www.fbi.gov/wanted/topten"
response3 = requests.get(url3)
soup3 = BeautifulSoup(response3.text, "html.parser")

soup3.find_all('h3')[0].get_text().strip()
# Out:
# 'ALEXIS FLORES'

# %%
name_h3s = soup3.find_all('h3')

# %%
names = []

# %%
for h3 in name_h3s:
    name_text = h3.get_text().strip()
    names.append(name_text)

# %%
names = pd.DataFrame(names)
names
# Out:
#                                     0
# 0                       ALEXIS FLORES
# 1         YULAN ADONAY ARCHAGA CARIAS
# 2      BHADRESHKUMAR CHETANBHAI PATEL
# 3            WILVER VILLEGAS-PALOMINO
# 4          ALEJANDRO ROSALES CASTILLO
# 5                       RUJA IGNATOVA
# 6                     ARNOLDO JIMENEZ
# 7             OMAR ALEXANDER CARDENAS
# 8                 MICHAEL JAMES PRATT
# 9   JOSE RODOLFO VILLARREAL-HERNANDEZ
# 10    federal bureau of investigation
# 11             FBI.gov Contact Center

# %%
#5 List all language names and number of related articles in the order they appear in wikipedia.org: url = 'https://www.wikipedia.org/'
url5 = "https://www.wikipedia.org/"
response5 = requests.get(url5)
soup5 = BeautifulSoup(response5.text, "html.parser")

soup5.find_all('strong')[1].get_text()
# Out:
# 'English'
